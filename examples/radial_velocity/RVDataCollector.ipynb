# %%
#from exotic.api.rv import RadialVelocityDatabase
import exotic.api.rv
from exotic.api.rv import RadialVelocityDatabase
from astroquery.simbad import Simbad
import csv
import logging
logger = logging.getLogger("ultranest")
logger.addHandler(logging.NullHandler())
logger.setLevel(logging.WARNING)
# Target set-up
print()
print("Enter RadialVelocityDatabase")
print()              
print("Input the name of the stellar target. Do not include a planet designation.")
target = input("What is the name of your target? ")
simbad_result_count=0
while simbad_result_count == 0:
    try:
        result_table = Simbad.query_object(target)
        simbad_result_count = len(result_table)
    except:
        simbad_result_count = 0
        print("Target not found.")
        target = input("What is the name of your target? ") 

new_rv_data = RadialVelocityDatabase(target)
df = new_rv_data.get_data(target)

nt = len(df['BJD'])

filetarget=target.replace(" ","")

with open('/Users/subercorley/EXOTIC/examples/radial_velocity/data/'+filetarget+'.csv', 'w', newline='') as file:
    fieldnames = ['target', 'BJD','rv','rv_err','ins_name','RA','DEC','rjd']
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    writer.writeheader()
    i=0
    while i<nt:
        writer.writerow({"target": df["target"][i],"BJD":df["BJD"][i],"rv":df["rv"][i],
                        "rv_err":df["rv_err"][i],"ins_name":df["ins_name"][i],
                         "RA":df["RA"][i],"DEC":df["DEC"][i],"rjd":df["rjd"][i]})
        i+=1
# Out:
# pyvo             version 1.4.2
#
# Enter RadialVelocityDatabase
#
# Input the name of the stellar target. Do not include a planet designation.
# What is the name of your target? WASP-77A
# Converted to decimal degrees. RA =  37.155239509  and DEC =  -7.0606599999999995
# WARNING: column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: NoResultsWarning: Query returned no results. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# gamma derived from NasaExoplanetArchive=  0.0
# enter DACE
#
# return length from Spectroscopy for alias=  19
# nt in normalizer get dace  19
# Number of DACE observations is: 19
# Average SNR DACE is: 383.62410
#
# Converted to decimal degrees. RA =  37.155239509  and DEC =  -7.0606599999999995
# WARNING: column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: NoResultsWarning: Query returned no results. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# gamma derived from NasaExoplanetArchive=  0.0
# enter HARPS15
#
# Number of HARPS observations is: 22
# Average SNR HARPS is: 970.97202
#
# Converted to decimal degrees. RA =  37.155239509  and DEC =  -7.0606599999999995
# WARNING: column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: NoResultsWarning: Query returned no results. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# gamma derived from NasaExoplanetArchive=  0.0
# enter eso espresso
#
# Saved file: ADP.2021-11-04T17:19:04.378.fits
# Saved file: ADP.2021-11-04T17:19:04.273.fits
# Saved file: ADP.2021-11-04T17:19:04.274.fits
# Saved file: ADP.2021-11-04T17:19:04.275.fits
# Saved file: ADP.2021-11-04T17:19:04.276.fits
# Saved file: ADP.2021-11-04T17:19:04.277.fits
# Saved file: ADP.2021-11-04T17:19:04.278.fits
# Saved file: ADP.2021-11-04T17:19:04.279.fits
# Saved file: ADP.2021-11-04T17:19:04.280.fits
# Saved file: ADP.2021-11-04T17:19:04.281.fits
# Saved file: ADP.2021-11-04T17:19:04.282.fits
# Saved file: ADP.2021-11-04T17:19:04.283.fits
# Saved file: ADP.2021-11-04T17:19:04.284.fits
# Saved file: ADP.2021-12-10T10:39:56.805.fits
# Saved file: ADP.2021-12-10T10:39:56.806.fits
# Saved file: ADP.2021-12-10T10:39:56.807.fits
# Saved file: ADP.2021-12-10T10:39:56.808.fits
# Saved file: ADP.2021-12-10T10:39:56.809.fits
# Saved file: ADP.2021-12-10T10:39:56.810.fits
# Saved file: ADP.2021-12-10T10:39:56.811.fits
# Saved file: ADP.2021-12-10T10:39:56.812.fits
# Saved file: ADP.2021-12-10T10:39:56.813.fits
# Saved file: ADP.2021-12-10T10:39:56.814.fits
# Saved file: ADP.2021-12-10T10:39:56.815.fits
# Saved file: ADP.2021-12-10T10:39:56.816.fits
# Saved file: ADP.2021-12-10T10:39:56.817.fits
# Saved file: ADP.2021-12-10T10:39:56.818.fits
# Saved file: ADP.2021-12-10T10:39:56.819.fits
# Saved file: ADP.2021-12-10T10:39:56.820.fits
# Saved file: ADP.2021-12-10T10:39:56.821.fits
# Saved file: ADP.2021-12-10T10:39:56.822.fits
# Number of ESPRESSO observations is: 154
# Average ESPRESSO is: 1242.96644
#
# Converted to decimal degrees. RA =  37.155239509  and DEC =  -7.0606599999999995
# WARNING: column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING: NoResultsWarning: Query returned no results. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# gamma derived from NasaExoplanetArchive=  0.0
# enter neid
#
# RA from Simbad=  37.155239509
# QDEC from Simbad=  -7.0606599999999995
# pos parameter=  circle 37.155239509 -7.0606599999999995 0.5
# submitting request...
# /Users/subercorley/anaconda3/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(
# Result downloaded to file [./criteria.tbl]
# NEID dnload_dir not present, no issue to proceed
# There is no data in the metadata table.
# no data for  WASP-77A
#
# Converted to decimal degrees. RA =  37.155239509  and DEC =  -7.0606599999999995
# WARNING: column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: NoResultsWarning: Query returned no results. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results.
# gamma derived from NasaExoplanetArchive=  0.0
# enter hires
#
# Converted to decimal degrees. RA =  37.155239509  and DEC =  -7.0606599999999995
# WARNING: column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_lum has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_lumerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_lumerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_logg has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_loggerr1 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.") [astropy.table.table]
# WARNING:astroquery:column st_loggerr2 has a unit but is kept as a MaskedColumn as an attempt to convert it to Quantity failed with:
# UnitTypeError("MaskedQuantity instances require normal units, not <class 'astropy.units.function.logarithmic.DexUnit'> instances.")
# WARNING: NoResultsWarning: Query returned no results. [astroquery.ipac.nexsci.nasa_exoplanet_archive.core]
# WARNING:astroquery:NoResultsWarning: Query returned no results.
# gamma derived from NasaExoplanetArchive=  0.0
# enter sophie
#
# average of rv_err = 1.6106012730161217
# Number of points before cleaning: 195
# Number of points after cleaning: 195
#
# List of instruments kept after cleaning:
# ['CORALIE' 'ESPRESSO' 'HARPS' 'HARPS15']
#
# Exit RadialVelocityDatabase
